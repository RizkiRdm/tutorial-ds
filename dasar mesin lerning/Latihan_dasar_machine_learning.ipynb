# %% [markdown]
# ## Identifikasi informasi dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# read file **test.csv**

# %%
test = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/credit-score-classification/test.csv')
test.head()
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# 0                2022.0        Good           809.98                35.030402
# 1                   4.0        Good           809.98                33.053114
# 2                   4.0        Good           809.98                33.811894
# 3                   4.0        Good           809.98                32.430559
# 4                   5.0        Good           605.03                25.926822
#
#        Credit_History_Age Payment_of_Min_Amount Total_EMI_per_month  \
# 0   22 Years and 9 Months                    No           49.574949
# 1  22 Years and 10 Months                    No           49.574949
# 2                     NaN                    No           49.574949
# 3   23 Years and 0 Months                    No           49.574949
# 4   27 Years and 3 Months                    No           18.816215
#
#    Amount_invested_monthly                 Payment_Behaviour  \
# 0       236.64268203272135    Low_spent_Small_value_payments
# 1       21.465380264657146  High_spent_Medium_value_payments
# 2       148.23393788500925   Low_spent_Medium_value_payments
# 3        39.08251089460281  High_spent_Medium_value_payments
# 4       39.684018417945296   High_spent_Large_value_payments
#
#       Monthly_Balance
# 0  186.26670208571772
# 1  361.44400385378196
# 2  264.67544623342997
# 3  343.82687322383634
# 4   485.2984336755923
#
# [5 rows x 27 columns]

# %% [markdown]
# Read file **train.csv**

# %%
train = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/credit-score-classification/train.csv')
train.head()
# Out:
# <ipython-input-3-5c984e7d12ed>:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv('https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/refs/heads/main/credit-score-classification/train.csv')
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
# 3            809.98                31.377862  22 Years and 4 Months
# 4            809.98                24.797347  22 Years and 5 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
# 3                     No           49.574949       199.4580743910713
# 4                     No           49.574949      41.420153086217326
#
#                   Payment_Behaviour     Monthly_Balance Credit_Score
# 0   High_spent_Small_value_payments  312.49408867943663         Good
# 1    Low_spent_Large_value_payments  284.62916249607184         Good
# 2   Low_spent_Medium_value_payments   331.2098628537912         Good
# 3    Low_spent_Small_value_payments  223.45130972736786         Good
# 4  High_spent_Medium_value_payments  341.48923103222177         Good
#
# [5 rows x 28 columns]

# %% [markdown]
# Menampilkan ringkasan informasi dataset

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
#  13  Type_of_Loan              88592 non-null   object
#  14  Delay_from_due_date       100000 non-null  int64
#  15  Num_of_Delayed_Payment    92998 non-null   object
#  16  Changed_Credit_Limit      100000 non-null  object
#  17  Num_Credit_Inquiries      98035 non-null   float64
#  18  Credit_Mix                100000 non-null  object
#  19  Outstanding_Debt          100000 non-null  object
#  20  Credit_Utilization_Ratio  100000 non-null  float64
#  21  Credit_History_Age        90970 non-null   object
#  22  Payment_of_Min_Amount     100000 non-null  object
#  23  Total_EMI_per_month       100000 non-null  float64
#  24  Amount_invested_monthly   95521 non-null   object
#  25  Payment_Behaviour         100000 non-null  object
#  26  Monthly_Balance           98800 non-null   object
#  27  Credit_Score              100000 non-null  object
# dtypes: float64(4), int64(4), object(20)
# memory usage: 21.4+ MB

# %% [markdown]
# Menampilkan statistik deskriptif dari dataset

# %%
train.describe(include="all")
# Out:
#             ID Customer_ID    Month    Name     Age        SSN Occupation  \
# count   100000      100000   100000   90015  100000     100000     100000
# unique  100000       12500        8   10139    1788      12501         16
# top     0x1602   CUS_0xd40  January  Langep      38  #F%$D@*&8    _______
# freq         1           8    12500      44    2833       5572       7062
# mean       NaN         NaN      NaN     NaN     NaN        NaN        NaN
# std        NaN         NaN      NaN     NaN     NaN        NaN        NaN
# min        NaN         NaN      NaN     NaN     NaN        NaN        NaN
# 25%        NaN         NaN      NaN     NaN     NaN        NaN        NaN
# 50%        NaN         NaN      NaN     NaN     NaN        NaN        NaN
# 75%        NaN         NaN      NaN     NaN     NaN        NaN        NaN
# max        NaN         NaN      NaN     NaN     NaN        NaN        NaN
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# count         100000           84998.000000      100000.000000  ...
# unique         18940                    NaN                NaN  ...
# top         36585.12                    NaN                NaN  ...
# freq              16                    NaN                NaN  ...
# mean             NaN            4194.170850          17.091280  ...
# std              NaN            3183.686167         117.404834  ...
# min              NaN             303.645417          -1.000000  ...
# 25%              NaN            1625.568229           3.000000  ...
# 50%              NaN            3093.745000           6.000000  ...
# 75%              NaN            5957.448333           7.000000  ...
# max              NaN           15204.633333        1798.000000  ...
#
#         Credit_Mix  Outstanding_Debt Credit_Utilization_Ratio  \
# count       100000            100000            100000.000000
# unique           4             13178                      NaN
# top       Standard           1360.45                      NaN
# freq         36479                24                      NaN
# mean           NaN               NaN                32.285173
# std            NaN               NaN                 5.116875
# min            NaN               NaN                20.000000
# 25%            NaN               NaN                28.052567
# 50%            NaN               NaN                32.305784
# 75%            NaN               NaN                36.496663
# max            NaN               NaN                50.000000
#
#             Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# count                    90970                 100000       100000.000000
# unique                     404                      3                 NaN
# top     15 Years and 11 Months                    Yes                 NaN
# freq                       446                  52326                 NaN
# mean                       NaN                    NaN         1403.118217
# std                        NaN                    NaN         8306.041270
# min                        NaN                    NaN            0.000000
# 25%                        NaN                    NaN           30.306660
# 50%                        NaN                    NaN           69.249473
# 75%                        NaN                    NaN          161.224249
# max                        NaN                    NaN        82331.000000
#
#        Amount_invested_monthly               Payment_Behaviour  \
# count                    95521                          100000
# unique                   91049                               7
# top                  __10000__  Low_spent_Small_value_payments
# freq                      4305                           25513
# mean                       NaN                             NaN
# std                        NaN                             NaN
# min                        NaN                             NaN
# 25%                        NaN                             NaN
# 50%                        NaN                             NaN
# 75%                        NaN                             NaN
# max                        NaN                             NaN
#
#                          Monthly_Balance Credit_Score
# count                              98800       100000
# unique                             98792            3
# top     __-333333333333333333333333333__     Standard
# freq                                   9        53174
# mean                                 NaN          NaN
# std                                  NaN          NaN
# min                                  NaN          NaN
# 25%                                  NaN          NaN
# 50%                                  NaN          NaN
# 75%                                  NaN          NaN
# max                                  NaN          NaN
#
# [11 rows x 28 columns]

# %% [markdown]
# Memeriksa jumlah nilai yang hilang di setiap kolom

# %%
missing_values = train.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Name                        9985
# Monthly_Inhand_Salary      15002
# Type_of_Loan               11408
# Num_of_Delayed_Payment      7002
# Num_Credit_Inquiries        1965
# Credit_History_Age          9030
# Amount_invested_monthly     4479
# Monthly_Balance             1200
# dtype: int64

# %% [markdown]
# Pisahkan kolom yang memiliki
# - value > 75%
# - value < 75

# %%
less = missing_values[missing_values < 1000].index
over = missing_values[missing_values >= 1000].index

# %% [markdown]
# atasi missing value dengan tipe data numerik

# %%
numeric_features = train[less].select_dtypes(include=['number']).columns
train[numeric_features] = train[numeric_features].fillna(train[numeric_features].median())

# %% [markdown]
# isi missing value dengan modus

# %%
kategorical_features = train[less].select_dtypes(include=['object']).columns

for column in kategorical_features:
    train[column] = train[column].fillna(train[column].mode()[0])

# %% [markdown]
# Menghapus kolom dengan banyak nilai yang hilang

# %%
df = train.drop(columns=over)
df.head()
# Out:
#        ID Customer_ID     Month   Age          SSN Occupation Annual_Income  \
# 0  0x1602   CUS_0xd40   January    23  821-00-0265  Scientist      19114.12
# 1  0x1603   CUS_0xd40  February    23  821-00-0265  Scientist      19114.12
# 2  0x1604   CUS_0xd40     March  -500  821-00-0265  Scientist      19114.12
# 3  0x1605   CUS_0xd40     April    23  821-00-0265  Scientist      19114.12
# 4  0x1606   CUS_0xd40       May    23  821-00-0265  Scientist      19114.12
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                  3                4              3           4
# 1                  3                4              3           4
# 2                  3                4              3           4
# 3                  3                4              3           4
# 4                  3                4              3           4
#
#    Delay_from_due_date Changed_Credit_Limit Credit_Mix Outstanding_Debt  \
# 0                    3                11.27          _           809.98
# 1                   -1                11.27       Good           809.98
# 2                    3                    _       Good           809.98
# 3                    5                 6.27       Good           809.98
# 4                    6                11.27       Good           809.98
#
#    Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                 26.822620                    No            49.574949
# 1                 31.944960                    No            49.574949
# 2                 28.609352                    No            49.574949
# 3                 31.377862                    No            49.574949
# 4                 24.797347                    No            49.574949
#
#                   Payment_Behaviour Credit_Score
# 0   High_spent_Small_value_payments         Good
# 1    Low_spent_Large_value_payments         Good
# 2   Low_spent_Medium_value_payments         Good
# 3    Low_spent_Small_value_payments         Good
# 4  High_spent_Medium_value_payments         Good

# %% [markdown]
# verifikasi missing value

# %%
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Mengatasi Outliers

# %%
for feature in numeric_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[feature])
    plt.title(f'Box Plot of {feature}')

plt.show()

# %% [markdown]
# Mengatasi outliers dengan menggunakan metode **IQR** (*Interquartile Range*)

# %%
# identifikasi sederhana outliers

Q1 = df[numeric_features].quantile(0.25)
Q3 = df[numeric_features].quantile(0.75)
IQR = Q3 - Q1

# %% [markdown]
# Hapus outliers berdasarkan perhitungan tersebut

# %%
condition = ~((df[numeric_features] < (Q1 - 1.5 * IQR)) | (df[numeric_features] > (Q3 + 1.5 * IQR))).any(axis=1)
df_filtered_numeric = df.loc[condition, numeric_features]

# Menggabungkan kembali dengan kolomg kategorikal
categorical_features = df.select_dtypes(include=['object']).columns
df = pd.concat([df_filtered_numeric, df.loc[condition, categorical_features]], axis=1)

# %% [markdown]
# Tampilkan output dari hasil mengatasi outliers

# %%
for feature in df:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[feature])
    plt.title(f'Box Plot of {feature}')

# %% [markdown]
# ## Normalization & standarization data

# %% [markdown]
# Normalisasi dan standarisasi adalah teknik preprocessing data yang digunakan untuk meyiapkan data sebelum analisis atau pemodelan.

# %% [markdown]
# ### Normalisasi
# Normalisasi (juga dikenal dengan penskalaan min-max) bertugas untuk mengubah fitur sehingga nilainya berada dalam rentang tertentu, biasanya antara 0 dan 1.

# %% [markdown]
# Berikut poin-poin yang menjadi pertimbangan ketika akan melakukan normalisasi :

# %% [markdown]
# - **Fitur dengan Skala Berbeda**: ketika fitur memiliki skala yang sangat berbeda dan Anda ingin menyamakan rentangnya.
#
# - **Model Berbasis Jarak**: jika Anda menggunakan algoritma yang bergantung pada jarak, seperti K-Nearest Neighbors (KNN) atau K-Means clustering, normalisasi dapat membantu karena model ini sensitif terhadap skala fitur.
#
# - **Data Tidak Terdistribusi Normal**: jika data tidak terdistribusi normal dan Anda ingin mengubah data menjadi rentang yang lebih seragam.

# %% [markdown]
# ### Standarisasi
# Standarisasi (juga dikenal sebagai penklaan **Z-score**) bertugas untuk mengubah skala pada suatu fitur sehingga memiliki rata-rata 0 dan standar deviasi 1.

# %% [markdown]
# Berikut poin-poin yang menjadi pertimbangan ketika akan melakukan standarisasi :

# %% [markdown]
# - **Data Berdistribusi Normal**: ketika data mengikuti distribusi normal (atau mendekati normal) dan Anda ingin mempertahankan informasi tentang distribusi data.
# - **Model Berbasis Regresi**: untuk algoritma yang memerlukan asumsi distribusi normal atau model linier seperti Regresi Linier, Standar, atau Logistic Regression.
# - **Data dengan Skala Berbeda**: ketika fitur memiliki skala yang berbeda tetapi Anda ingin memastikan bahwa setiap fitur berkontribusi secara proporsional tanpa mengubah distribusi data secara signifikan.

# %% [markdown]
# ### perbedaan antara normalisasi dan standarisasi
#
#
#
# *   **Normalisasi** : mengubah data ke dalam rentang [0,1]. Ideal untuk model berbasis jarak dan data yang tidak terdistribusi.
# *   **Standarisasi** : mengubah data sehingga rata-rata menjadi atau mendekati 0 dan standar deviasi menjadi 1

# %% [markdown]
# Standarisasi data

# %%
from sklearn.preprocessing import StandardScaler

# Standardisasi fitur numerik
scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %% [markdown]
# melakukan perbandingan data antara sesudah dan sebelum dilakukan standarisasi

# %%
# Histogram sebelum standarisasi
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)

sns.histplot(train[numeric_features[3]], kde=True)

# title histogram
plt.title("Histogram Sebelum Standardisasi")
# Out:
# Text(0.5, 1.0, 'Histogram Sebelum Standardisasi')

# %%
# Histogram setelah standarisasi
plt.subplot(1, 2, 2)

sns.histplot(df[numeric_features[3]], kde=True)

# title histogram
plt.title("Histogram Sesudah Standardisasi")
# Out:
# Text(0.5, 1.0, 'Histogram Sesudah Standardisasi')

# %% [markdown]
# ## Menangani Duplikasi data

# %% [markdown]
# Perikas data yang sudah melewati tahapan-tahapan sebelumnya.

# %%
# Identifikasi baris duplikat
duplicates = df.duplicated()


# kondisi jika ada duplikasi data
if duplicates.any():
    print("Terdapat baris duplikat dalam dataset.")

    df = df.drop_duplicates()
    print("dataframe setelah menghapus duplikat :")
    print(df)
else:
    print("Tidak ada baris duplikat dalam dataset.")
    print(df[duplicates])
# Out:
# Tidak ada baris duplikat dalam dataset.
# Empty DataFrame
# Columns: [Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Delay_from_due_date, Credit_Utilization_Ratio, Total_EMI_per_month, ID, Customer_ID, Month, Age, SSN, Occupation, Annual_Income, Num_of_Loan, Changed_Credit_Limit, Credit_Mix, Outstanding_Debt, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score]
# Index: []

# %% [markdown]
# ## Mengonversi tipe data

# %% [markdown]
# Sebagian besar algoritma machine learning didasarkan pada operasi matematika yang melibatkan perhitungan jarak, gradien, atau distribusi data.
# Misalnya, regresi linier menghitung persamaan garis menggunakan koefisien yang diterapkan pada fitur numerik. Jika data inputan berupa kategori (seperti "merah," "biru," "hijau"), tidak ada cara langsung untuk memasukkan nilai kategori tersebut ke dalam perhitungan matematika.

# %% [markdown]
# Banyak algoritma, terutama yang berbasis jarak (seperti KNN), memerlukan cara untuk mengukur jarak antar titik data. Oleh karena itu jika data bertipe kategori menyebabkan model tidak dapat mengukur jarak, misalnya, tidak ada jarak matematis yang berarti antara "merah" dan "biru."

# %% [markdown]
# Untuk mengatasi masalah ini, data kategorikal biasanya diubah menjadi bentuk numerik yang dapat dipahami oleh model yang biasa disebut encoding. Berikut beberapa contoh umum hal yang bisa kita lakukan untuk mengatasi permasalahan ini.

# %% [markdown]
# - **One-Hot Encoding** : mengubah setiap kategori menjadi kolom biner terpisah dengan nilai 0 atau 1 (bisa juga True atau False).
#
# - **Label Encoding** : memberikan label numerik untuk setiap kategori, meskipun ini hanya cocok untuk data kategorikal ordinal
#
# - **Ordinal Encoding** : mengonversi kategori yang memiliki urutan menjadi nilai numerik yang mencerminkan urutan tersebut.

# %%
category_features = df.select_dtypes(include=['object']).columns
df[category_features]
# Out:
#             ID Customer_ID     Month   Age          SSN Occupation  \
# 0       0x1602   CUS_0xd40   January    23  821-00-0265  Scientist
# 1       0x1603   CUS_0xd40  February    23  821-00-0265  Scientist
# 2       0x1604   CUS_0xd40     March  -500  821-00-0265  Scientist
# 3       0x1605   CUS_0xd40     April    23  821-00-0265  Scientist
# 4       0x1606   CUS_0xd40       May    23  821-00-0265  Scientist
# ...        ...         ...       ...   ...          ...        ...
# 99994  0x25fe8  CUS_0x942c     March    25  078-73-5990   Mechanic
# 99995  0x25fe9  CUS_0x942c     April    25  078-73-5990   Mechanic
# 99996  0x25fea  CUS_0x942c       May    25  078-73-5990   Mechanic
# 99998  0x25fec  CUS_0x942c      July    25  078-73-5990   Mechanic
# 99999  0x25fed  CUS_0x942c    August    25  078-73-5990   Mechanic
#
#       Annual_Income Num_of_Loan Changed_Credit_Limit Credit_Mix  \
# 0          19114.12           4                11.27          _
# 1          19114.12           4                11.27       Good
# 2          19114.12           4                    _       Good
# 3          19114.12           4                 6.27       Good
# 4          19114.12           4                11.27       Good
# ...             ...         ...                  ...        ...
# 99994      39628.99           2                  9.5          _
# 99995      39628.99           2                 11.5          _
# 99996      39628.99           2                 11.5          _
# 99998      39628.99           2                 11.5       Good
# 99999     39628.99_           2                 11.5       Good
#
#       Outstanding_Debt Payment_of_Min_Amount  \
# 0               809.98                    No
# 1               809.98                    No
# 2               809.98                    No
# 3               809.98                    No
# 4               809.98                    No
# ...                ...                   ...
# 99994           502.38                    No
# 99995           502.38                    No
# 99996           502.38                    No
# 99998           502.38                    No
# 99999           502.38                    No
#
#                       Payment_Behaviour Credit_Score
# 0       High_spent_Small_value_payments         Good
# 1        Low_spent_Large_value_payments         Good
# 2       Low_spent_Medium_value_payments         Good
# 3        Low_spent_Small_value_payments         Good
# 4      High_spent_Medium_value_payments         Good
# ...                                 ...          ...
# 99994  High_spent_Medium_value_payments         Poor
# 99995   High_spent_Large_value_payments         Poor
# 99996  High_spent_Medium_value_payments         Poor
# 99998    Low_spent_Large_value_payments     Standard
# 99999                            !@9#%8         Poor
#
# [84532 rows x 14 columns]

# %% [markdown]
# ### ONE HOT ENCODING

# %%
df_one_hot = pd.get_dummies(df, columns=category_features)
df_one_hot.head()

# %% [markdown]
# ### LABEL ENCODING
# Label encoding memerlukan sebuah library pendukung untuk proses pengerjaannya, seperti menggunakan library **LabelEncoder** dar **Sklearn**

# %%
from sklearn.preprocessing import LabelEncoder

# Inisialisasi LabelEncoder
# label_encoder = LabelEncoder()
# df_lencoder = pd.DataFrame()

# # Melakukan label encoding pada setiap kolom kategorikal
# for col in category_features:
#     df_lencoder[col] = label_encoder.fit_transform(df[col])

# # Menampilkan hasil
# df_lencoder.head()

label_encoder = LabelEncoder()
df_lencoder = df.copy()

# Melakukan label encoding pada setiap kolom kategorikal
for col in category_features:
    df_lencoder[col] = label_encoder.fit_transform(df[col])

# menampilkan hasil
df_lencoder.head()

# %% [markdown]
# ## Exploratory dan explanatory data analysis

# %%
df_lencoder.head()

# %% [markdown]
# Periksa kembali missing value dari dataset yang akan digunakan

# %%
# menghitung jumlah dan presentase missing values di setiap kolom

missing_values = df_lencoder.isnull().sum()
missing_percentage = (missing_values / len(df_lencoder)) * 100

# menampilkan hasil
missing_data = pd.DataFrame({
    'Missing values': missing_values,
    'Percentage' : missing_percentage
}).sort_values(by="Missing values", ascending=False)

# Menampilkan kolong degngan missing values
missing_data[missing_data['Missing values'] > 0]

# %% [markdown]
# Tidak ada missing value karena sudah ditangani sebelumnya.Selanjutnya lakukan analisis deskriptif dengan membuat histogram agar distribusi data lebih terlihat dengan menggunakan fungsi **.describe()**

# %%
# hitung jumlah variable
num_vars = df_lencoder.shape[1]


n_col = 3
n_rows = -(-num_vars // n_col)

# membuat subplot untuk setiap kolom numerik
fig, axes = plt.subplots(n_rows, n_col, figsize=(20, n_rows * 3))

# flatten axes array
axes = axes.flatten()

# looping untuk setiap kolom numerik
for i, column in enumerate(df_lencoder.columns):
    df_lencoder[column].hist(bins=20, ax=axes[i], edgecolor='black')
    axes[i].set_title(column)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# menghilangkan subplot yang tidak digunakan
for i in range(num_vars, n_rows * n_col):
    fig.delaxes(axes[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# Selanjutnya, visualisasikan distribusi beberapa kolom serta melihat korelasi antara variabel numerik.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualisasi distribusi data untuk beberapa kolom
columns_to_plot = ['OverallQual', 'YearBuilt', 'LotArea', 'SaleType', 'SaleCondition']

plt.figure(figsize=(15, 10))
for i, column in enumerate(columns_to_plot, 1):

    if column in df_lencoder.columns:
        plt.subplot(2, 3, i)
        sns.histplot(df_lencoder[column], kde=True, bins=30)
        plt.title(f'Distribution of {column}')
    else :
        print(f"Column '{column}' not found in DataFrame")


plt.tight_layout()
plt.show()

# %% [markdown]
# Berikutnya, lakukan buat anlisis korelasi dengan membuat Matriks korelasi untuk menunjukkan beberapa hubungan penting antara variabel-variabel yang ada dalam dataset. Biasanya warna yang lebih terang atau lebih gelap mengindikasikan korelasi yang lebih kuat (positif atau negatif). Untuk melakukan analisis korelasi Anda dapat menggunakan kode berikut sebagai panduan awal.

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df_lencoder.corr()

sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# Membuat korelasi antara saleCondition dengan variable lainnya

# %%
# Menghitung korelasi antara variable target dan semua variable lainnya
# Check if 'SalePrice' is in the columns
if 'SalePrice' in df_lencoder.columns:
    target_corr = df_lencoder.corr()['SalePrice']
else:
    print("Column 'SalePrice' not found in DataFrame. Please ensure it exists and is numerical.")

# (Opsional) Mengurutkan hasil korelasi berdasarkan korelasi
target_corr_sorted = target_corr.abs().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
target_corr_sorted.plot(kind='bar')
plt.title(f'Correlation with SalePrice')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Data Splitting

# %%
import sklearn

# %% [markdown]
# Memisahkan fitur (x) dan target (y)

# %%
x = df_lencoder.drop(columns=['SalePrice'])
y = df_lencoder['SalePrice']

# %% [markdown]
# Untuk membagi dataset menjadi train set dan test set, kita bisa menggunakan fungsi train_test_split. Fungsi ini memerlukan beberapa parameter utama:

# %% [markdown]
# - **X**: kumpulan atribut atau fitur dari dataset, yaitu semua kolom kecuali kolom target (pada kasus ini SalePrice).
# - **y**: target atau label yang akan kita prediksi merupakan kolom yang ingin kita pisahkan (pada kasus ini SalePrice).
# - **test_size**: persentase dari data yang akan digunakan sebagai test set. Misalnya, ketika Anda menentukan test_size=0.2, 20% dari data akan menjadi test set, dan 80% sisanya akan menjadi train set.
# - **random_state**: parameter yang memastikan pemisahan data yang konsisten setiap kali fungsi tersebut dijalankan. Parameter ini mengontrol pengacakan saat membagi dataset sehingga dengan menetapkan random_state hasil pembagian data (train set dan test set) akan selalu sama. Hal ini penting untuk memastikan eksperimen yang dapat direproduksi dan evaluasi model yang konsisten. Namun, parameter ini juga dapat memiliki kekurangan yaitu model tidak akan menerima inputan baru yang mungkin akan lebih baik dari sebelumnya.

# %% [markdown]
# Ketika Anda menjalankan train_test_split, fungsi ini akan mengembalikan empat bagian data seperti berikut.

# %% [markdown]
# - **X_train**: fitur untuk train set.
# - **X_test**: fitur untuk test set.
# - **y_train**: target untuk train set.
# - **y_test**: target untuk test set.

# %% [markdown]
# Ini berarti setelah pemanggilan fungsi, Anda memiliki dua bagian data: satu untuk melatih model (train set) dan satu lagi untuk menguji model (test set).

# %%
# membagi data set menjadi training dan testing

from sklearn.model_selection import train_test_split

x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=1)

# %% [markdown]
# **Pro tips**
#
# - **Selalu Gunakan random_state**: untuk memastikan hasil yang konsisten dan dapat direproduksi setiap kali Anda menjalankan kode Anda.
# - **Pertimbangkan Penggunaan stratify**: ini sangat penting jika Anda memiliki dataset dengan kelas yang tidak seimbang, karena memastikan bahwa setiap subset memiliki distribusi kelas yang sama.
# - **Evaluasi dengan Cross-Validation**: meskipun train_test_split memberikan cara sederhana untuk membagi data, cross-validation dapat memberikan evaluasi model yang lebih robust, terutama jika dataset Anda kecil.

# %%
# Menghitung panjang/jumlah data
print(f"Jumlah data : {len(x)}")

# Menghitung panjang/jumlah data pada x_train
print(f"Jumlah data latih : {len(x_train)}")

# Menghitung panjang/jumlah data pada x_test
print(f"Jumlah data latih : {len(x_test)}")

# %% [markdown]
# # Pembangunan model

# %% [markdown]
# ## Latih data dengan 3 algoritma yang berbeda

# %% [markdown]
# - Least Angle Regression

# %%
from sklearn import linear_model
lars = linear_model.Lars(n_nonzero_coefs=1).fit(x_train, y_train)

# %% [markdown]
# - Linear Regression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression().fit(x_train,y_train)

# %% [markdown]
# - Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
GBR = GradientBoostingRegressor(random_state=184)
GBR.fit(x_train,y_train)

# %% [markdown]
# ## Evaluasi model

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Evaluasi pada LARS
pred_lars = lars.predict(x_test)
mae_lars = mean_absolute_error(y_test, pred_lars)
mse_lars = mean_squared_error(y_test, pred_lars)
r2_lars = r2_score(y_test, pred_lars)

data = {
    "MAE" : [mae_lars],
    "MSE" : [mse_lars],
    "R2" : [r2_lars],
}

df_results = pd.DataFrame(data, index=['Lars'])
df_results

# %% [markdown]
# Evaluasi pada model linear regression

# %%
# evaluasi model linear regression
pred_LR = LR.predict(x_test)
mae_LR = mean_absolute_error(y_test, pred_LR)
mse_LR = mean_squared_error(y_test, pred_LR)
r2_LR = r2_score(y_test, pred_LR)

# Menambahkan hasil ke dalam dataframe
df_results.loc['LinearRegression'] = [mae_LR, mse_LR, r2_LR]
df_results

# %% [markdown]
# Evaluasi pada model Gradient Booster Regressor

# %%
pred_GBR = GBR.predict(x_test)
mae_GBR = mean_absolute_error(y_test, pred_GBR)
mse_GBR = mean_squared_error(y_test, pred_GBR)
r2_GBR = r2_score(y_test, pred_GBR)

# Menambahkan hasil ke dalam dataframe
df_results.loc['GradientBoostingRegressor'] = [mae_GBR, mse_GBR, r2_GBR]
df_results

# %% [markdown]
# ## Menyimpan model

# %%
import joblib
joblib.dump(GBR, 'gbr_model.joblib')
